# %%
import json

# Path to your JSON file
json_file_path = "/Users/davidq/Desktop/UMICH/700_LLM/Project/llm_uncertainty/data/jsons/wiki_test.json"

# Load the JSON file
with open(json_file_path, "r") as file:
    data = json.load(file)

len(list(sorted(data.items(), key=lambda t: t[0])))
# Out:
# 2900

# %%
import pickle

# Path to the pickle file
pickle_file = "wiki_test_meta-llama_Llama-3.2-1B_0.pickle"

# Load the data
with open(pickle_file, "rb") as fp:
    data = pickle.load(fp)

# Display the loaded data
print(data)
# Out:
# {'...Too': tensor([[ 7.0938,  9.0625, 13.3750,  ..., -3.7812, -3.7812, -3.7812],
#         [10.9375, 10.3125,  9.5000,  ...,  0.1924,  0.1924,  0.1914],
#         [15.6875, 13.1250,  8.6250,  ..., -0.3164, -0.3164, -0.3164],
#         ...,
#         [ 5.1250,  6.0000,  3.2500,  ..., -3.6562, -3.6562, -3.6562],
#         [14.1250, 11.5625, 10.8750,  ...,  1.9453,  1.9453,  1.9453],
#         [ 4.4062,  4.4375,  6.4375,  ..., -0.5938, -0.5898, -0.5898]]), "1,1'-Ferrocenetrisulfide": tensor([[ 7.0938,  9.0625, 13.3750,  ..., -3.7812, -3.7812, -3.7812],
#         [ 8.7500, 11.0000,  9.6250,  ..., -2.4375, -2.4375, -2.4375],
#         [ 7.8438,  2.2344,  7.7812,  ...,  0.6641,  0.6641,  0.6641],
#         ...,
#         [ 6.0312,  7.6875,  5.3750,  ..., -0.6680, -0.6641, -0.6680],
#         [11.4375, 11.1250,  8.8125,  ...,  1.0078,  1.0078,  1.0000],
#         [ 6.0000,  3.5000,  6.0625,  ..., -0.4375, -0.4375, -0.4375]])}
